# %%
# !git clone https://github.com/ekondrashov25/anti-spoofing-hw.git
# Out:
# Cloning into 'anti-spoofing-hw'...
# remote: Enumerating objects: 241, done.
# remote: Counting objects: 100% (241/241), done.
# remote: Compressing objects: 100% (164/164), done.
# remote: Total 241 (delta 105), reused 185 (delta 65), pack-reused 0 (from 0)
# Receiving objects: 100% (241/241), 57.66 KiB | 1.44 MiB/s, done.
# Resolving deltas: 100% (105/105), done.

# %%
# %cd anti-spoofing-hw
# Out:
# /kaggle/working/anti-spoofing-hw

# %%
# !pip install -r requirements.txt --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.6/796.6 kB 4.5 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.2/226.2 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 22.2 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 65.1 MB/s eta 0:00:0000:01:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.6/470.6 kB 33.3 MB/s eta 0:00:00

# %%
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
wandb_key = user_secrets.get_secret("WANDB_API_KEY")

import wandb
wandb.login(key=wandb_key)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: egorkondr4 (egorkondr432) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !python3 train.py --config-name=asvspoof writer.run_name=lcnn_v2_mel writer.mode=online \
    dataloader.batch_size=64 lr_scheduler.T_max=9900 \
    trainer.n_epochs=25 trainer.early_stop=10
# Out:
# Logging git commit and patch...
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: egorkondr4 (egorkondr432) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run vu96owz7 (0.5s)
# wandb: ⣯ setting up run vu96owz7 (0.5s)
# wandb: ⣟ setting up run vu96owz7 (0.5s)
# wandb: ⡿ setting up run vu96owz7 (0.5s)
# wandb: ⢿ setting up run vu96owz7 (0.5s)
# wandb: ⣻ setting up run vu96owz7 (1.0s)
# wandb: ⣽ setting up run vu96owz7 (1.0s)
# wandb: ⣾ setting up run vu96owz7 (1.0s)
# wandb: ⣷ setting up run vu96owz7 (1.0s)
# wandb: ⣯ setting up run vu96owz7 (1.0s)
# wandb: ⣟ setting up run vu96owz7 (1.5s)
# wandb: ⡿ setting up run vu96owz7 (1.5s)
# wandb: Tracking run with wandb version 0.26.1
# ...

# %%
# !python3 inference.py --config-name=asvspoof_inference \
    inferencer.from_pretrained=saved/lcnn_v2_mel/model_best.pth \
    inferencer.submission_name=eakondrashov \
    dataloader.batch_size=64
# Out:
# LCNN(
#   (nn): Sequential(
#     (0): MFM(
#       (conv): Conv2d(1, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): MFM(
#       (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): MFM(
#       (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MFM(
#       (conv): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (8): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): MFM(
#       (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
# ...
